# %%
import pandas as pd 
import numpy as np 
import re
import sys

from nltk import word_tokenize
from keras.models import Sequential, Model
from keras.layers.embeddings import Embedding
from keras.models import model_from_json
from keras.layers import Input, Activation, Dense, Dropout
from keras.layers import LSTM, Bidirectional
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
quotables = pd.read_csv('author-quote.txt', delimiter='\t', header=None)
quotables = quotables.rename(columns={0:'author', 1:'quote'})

# %%
quotables.sample(20)
# Out:
#                       author  \
# 27408         Paul Gascoigne
# 4887             Brion James
# 17754            Jim Capaldi
# 30507  Saint Teresa of Avila
# 34103          Tryon Edwards
# 5005           Bruce Babbitt
# 27880        Peter Gallagher
# 7237             Coco Chanel
# 33523        Thornton Wilder
# 19070             John Locke
# 34777         Virginia Satir
# 9144          Dorothy Hamill
# 901             Albert Ellis
# 16341           Jane Campion
# 32278            Steve Earle
# 16729         Jeanne Calment
# 6332    Charlotte Gainsbourg
# 4358               Bob Dylan
# 20284          Julius Caesar
# 25471      Millicent Fawcett
#
#                                                    quote
# 27408  I don't really do pranks any more. I have a la...
# 4887   You know, stand-up comedy is where I pretty mu...
# 17754         Traffic was very, very free. It was great.
# 30507  God has been very good to me, for I never dwel...
# 34103  Science has sometimes been said to be opposed ...
# 5005   I look back on it, yeah, I'm in a much worse f...
# 27880  I feel like I won the Lotto, as far as that sh...
# 7237   Since everything is in our heads, we had bette...
# 33523  Those who are silent, self-effacing and attent...
# 19070  As people are walking all the time, in the sam...
# 34777  What lingers from the parent's individual past...
# 9144   I was just ice skating. I had no concept of th...
# 901    Rational beliefs bring us closer to getting go...
# 16341  I think women don't grow up with the harsh wor...
# 32278  Me, I'm spiritually retarded, I need to be kne...
# 16729  Always keep your smile. That's how I explain m...
# 6332   It's more than a job. It's very personal, so w...
# 4358   I'm more of an adventurous type than a relatio...
# 20284             Caesar's wife must be above suspicion.
# 25471  The assertion of failure coming from such pers...

# %%
len(list(quotables.author.unique()))
# Out:
# 2297

# %%
quotables.loc[quotables.author == 'Anne Frank']
# Out:
#           author                                              quote
# 2346  Anne Frank       Whoever is happy will make others happy too.
# 2347  Anne Frank  Despite everything, I believe that people are ...
# 2348  Anne Frank  Think of all the beauty still left around you ...
# 2349  Anne Frank  The best remedy for those who are afraid, lone...
# 2350  Anne Frank  Everyone has inside of him a piece of good new...
# 2351  Anne Frank  Parents can only give good advice or put them ...
# 2352  Anne Frank  Laziness may appear attractive, but work gives...
# 2353  Anne Frank  I don't think of all the misery but of the bea...
# 2354  Anne Frank  How wonderful it is that nobody need wait a si...
# 2355  Anne Frank  In spite of everything I still believe that pe...
# 2356  Anne Frank  We all live with the objective of being happy;...
# 2357  Anne Frank  How true Daddy's words were when he said: all ...
# 2358  Anne Frank  It's really a wonder that I haven't dropped al...
# 2359  Anne Frank  And finally I twist my heart round again, so t...
# 2360  Anne Frank  The final forming of a person's character lies...
# 2361  Anne Frank  Who would ever think that so much went on in t...
# 2362  Anne Frank                            I live in a crazy time.
# 2363  Anne Frank  I simply can't build my hopes on a foundation ...
# 2364  Anne Frank             No one has ever become poor by giving.
# 2365  Anne Frank  I keep my ideals, because in spite of everythi...
# 2366  Anne Frank  Boys will be boys. And even that wouldn't matt...
# 2367  Anne Frank  I soothe my conscience now with the thought th...
# 2368  Anne Frank  I must uphold my ideals, for perhaps the time ...
# 2369  Anne Frank  If I read a book that impresses me, I have to ...

# %%
quotables['len_quotes'] = quotables.quote.map(lambda s: len(s))

# %%
quotes = list(quotables.quote + '\n')

# %%
removed_char = ['#', '$', '%', '(', ')', '=', ';' ,':',  '*', '+', '£' , '—','’']  
quotes_cleaned = []

for quote in quotes: 
    # remove unused character
    for s_char in removed_char:
        quote = quote.replace(s_char, ' ')
    
    # remove white space
    pattern = re.compile(r'\s{2,}')
    quote = re.sub(pattern, ' ', quote)

    quotes_cleaned.append(quote)

text = ' '.join(quotes_cleaned)
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 15
step = 6
sentences = []
next_chars = []

for quote in quotes_cleaned:
    for i in range(0, len(quote) - maxlen, step):
        sentences.append(quote[i: i + maxlen])
        next_chars.append(quote[i + maxlen])
    sentences.append(quote[-maxlen:])
    next_chars.append(quote[-1])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 753142

# %%
sentences
# Out:
# ['If you live to ',
#  ' live to be a h',
#  'to be a hundred',
#  'a hundred, I wa',
#  'red, I want to ',
#  ' want to live t',
#  'to live to be a',
#  'e to be a hundr',
#  'e a hundred min',
#  'ndred minus one',
#  'minus one day s',
#  'one day so I ne',
#  'y so I never ha',
#  ' never have to ',
#  ' have to live w',
#  'to live without',
#  'e without you.\n',
#  "Promise me you'",
#  "e me you'll alw",
#  "ou'll always re",
#  'always remember',
#  " remember You'r",
#  "ber You're brav",
#  "u're braver tha",
#  'raver than you ',
#  'than you believ',
#  'ou believe, and',
#  'ieve, and stron',
#  'and stronger th',
#  'ronger than you',
#  ' than you seem,',
#  'you seem, and s',
#  'em, and smarter',
#  'd smarter than ',
#  'ter than you th',
#  'han you think.\n',
#  'Did you ever st',
#  'u ever stop to ',
#  ' stop to think,',
#  'to think, and f',
#  'nk, and forget ',
#  'd forget to sta',
#  'et to start aga',
#  'o start again?\n',
#  'Organizing is w',
#  'zing is what yo',
#  's what you do b',
#  ' you do before ',
#  'o before you do',
#  're you do somet',
#  ' do something, ',
#  'mething, so tha',
#  'g, so that when',
#  'that when you d',
#  'hen you do it, ',
#  'u do it, it is ',
#  't, it is not al',
#  'is not all mixe',
#  ' all mixed up.\n',
#  'Weeds are flowe',
#  'are flowers too',
#  'owers too, once',
#  'too, once you g',
#  'nce you get to ',
#  'u get to know t',
#  ' to know them.\n',
#  "You can't stay ",
#  "n't stay in you",
#  'ay in your corn',
#  'your corner of ',
#  'orner of the fo',
#  'of the forest w',
#  ' forest waiting',
#  't waiting for o',
#  'ing for others ',
#  'r others to com',
#  'rs to come to y',
#  'come to you. Yo',
#  'o you. You have',
#  ' You have to go',
#  'ave to go to th',
#  ' go to them som',
#  ' them sometimes',
#  'hem sometimes.\n',
#  'The third-rate ',
#  'ird-rate mind i',
#  'te mind is only',
#  'd is only happy',
#  'nly happy when ',
#  'ppy when it is ',
#  'en it is thinki',
#  'is thinking wit',
#  'nking with the ',
#  'with the majori',
#  'he majority. Th',
#  'ority. The seco',
#  ' The second-rat',
#  'econd-rate mind',
#  'rate mind is on',
#  'ind is only hap',
#  ' only happy whe',
#  'happy when it i',
#  'when it is thin',
#  't is thinking w',
#  'hinking with th',
#  'g with the mino',
#  ' the minority. ',
#  'inority. The fi',
#  'y. The first-ra',
#  ' first-rate min',
#  '-rate mind is o',
#  'mind is only ha',
#  's only happy wh',
#  ' happy when it ',
#  ' when it is thi',
#  'it is thinking.',
#  't is thinking.\n',
#  'Bores can be di',
#  'can be divided ',
#  ' divided into t',
#  'ed into two cla',
#  'o two classes t',
#  'classes those w',
#  's those who hav',
#  'e who have thei',
#  'have their own ',
#  'heir own partic',
#  'wn particular s',
#  'ticular subject',
#  'r subject, and ',
#  'ect, and those ',
#  'nd those who do',
#  'se who do not n',
#  ' do not need a ',
#  't need a subjec',
#  'eed a subject.\n',
#  'What I say is t',
#  ' say is that, i',
#  's that, if a fe',
#  ', if a fellow r',
#  ' fellow really ',
#  'w really likes ',
#  'ly likes potato',
#  'es potatoes, he',
#  'atoes, he must ',
#  ' he must be a p',
#  'st be a pretty ',
#  'a pretty decent',
#  'ty decent sort ',
#  'ent sort of fel',
#  'ort of fellow.\n',
#  'My spelling is ',
#  'lling is Wobbly',
#  "is Wobbly. It's",
#  "bly. It's good ",
#  "t's good spelli",
#  'od spelling but',
#  'lling but it Wo',
#  'but it Wobbles,',
#  ' Wobbles, and t',
#  'es, and the let',
#  'd the letters g',
#  'letters get in ',
#  's get in the wr',
#  'in the wrong pl',
#  ' wrong places.\n',
#  'To the uneducat',
#  ' uneducated, an',
#  'cated, an A is ',
#  ' an A is just t',
#  'is just three s',
#  't three sticks.',
#  ' three sticks.\n',
#  'One of the adva',
#  ' the advantages',
#  'dvantages of be',
#  'ges of being di',
#  ' being disorder',
#  ' disorderly is ',
#  'derly is that o',
#  'is that one is ',
#  't one is consta',
#  'is constantly m',
#  'stantly making ',
#  'y making exciti',
#  'ng exciting dis',
#  'iting discoveri',
#  'g discoveries.\n',
#  "Tiggers don't l",
#  "s don't like ho",
#  "'t like honey.\n",
#  'Never forget me',
#  'forget me, beca',
#  ' me, because if',
#  'ecause if I tho',
#  ' if I thought y',
#  'thought you wou',
#  "t you would, I'",
#  "would, I'd neve",
#  " I'd never leav",
#  'd never leave.\n',
#  'Almost anyone c',
#  ' anyone can be ',
#  'e can be an aut',
#  'be an author th',
#  'author the busi',
#  ' the business i',
#  'usiness is to c',
#  's is to collect',
#  'o collect money',
#  'ect money and f',
#  'ney and fame fr',
#  'd fame from thi',
#  ' from this stat',
#  'this state of b',
#  'tate of being.\n',
#  'If one is to be',
#  ' is to be calle',
#  ' be called a li',
#  'lled a liar, on',
#  ' liar, one may ',
#  ' one may as wel',
#  'ay as well make',
#  'well make an ef',
#  'ake an effort t',
#  ' effort to dese',
#  't to deserve th',
#  'eserve the name',
#  'erve the name.\n',
#  'Golf is so popu',
#  's so popular si',
#  'opular simply b',
#  ' simply because',
#  'y because it is',
#  'use it is the b',
#  ' is the best ga',
#  'e best game in ',
#  ' game in the wo',
#  'in the world at',
#  ' world at which',
#  ' at which to be',
#  'ich to be bad.\n',
#  'You will be bet',
#  'll be better ad',
#  'better advised ',
#  ' advised to wat',
#  'ed to watch wha',
#  'watch what we d',
#  'what we do inst',
#  'e do instead of',
#  'nstead of what ',
#  ' of what we say',
#  'f what we say.\n',
#  'I suppose that ',
#  'ose that every ',
#  'at every one of',
#  'ry one of us ho',
#  ' of us hopes se',
#  ' hopes secretly',
#  ' secretly for i',
#  'tly for immorta',
#  'r immortality t',
#  'rtality to leav',
#  'y to leave, I m',
#  'eave, I mean, a',
#  'I mean, a name ',
#  ', a name behind',
#  'me behind him w',
#  'ind him which w',
#  'm which will li',
#  'h will live for',
#  ' live forever i',
#  'forever in this',
#  'r in this world',
#  'his world, what',
#  'rld, whatever h',
#  'hatever he may ',
#  'r he may be doi',
#  'ay be doing, hi',
#  'doing, himself,',
#  ' himself, in th',
#  'lf, in the next',
#  ', in the next.\n',
#  'No sensible aut',
#  'sible author wa',
#  'author wants an',
#  ' wants anything',
#  ' anything but p',
#  'ing but praise.',
#  'ng but praise.\n',
#  'The key to maki',
#  'y to making hea',
#  'aking healthy d',
#  'healthy decisio',
#  'y decisions is ',
#  'sions is to res',
#  'is to respect y',
#  'respect your fu',
#  't your future s',
#  ' future self. H',
#  'e self. Honor h',
#  '. Honor him or ',
#  'r him or her. T',
#  'or her. Treat h',
#  '. Treat him or ',
#  't him or her li',
#  'or her like you',
#  ' like you would',
#  'you would treat',
#  'uld treat a fri',
#  'eat a friend or',
#  'friend or a lov',
#  ' or a loved one',
#  'loved one. A St',
#  'one. A Stanford',
#  ' Stanford study',
#  'ord study showe',
#  'udy showed that',
#  'owed that those',
#  'hat those who s',
#  'ose who saw a p',
#  'o saw a photo o',
#  'a photo of thei',
#  'o of their futu',
#  'heir future sel',
#  'uture self made',
#  'self made smart',
#  'ade smarter fin',
#  'arter financial',
#  'financial decis',
#  'ial decisions.\n',
#  'I have little s',
#  ' little shame, ',
#  'e shame, no dig',
#  'e, no dignity -',
#  'dignity - all i',
#  'y - all in the ',
#  'l in the name o',
#  'he name of a be',
#  'e of a better c',
#  ' better cause.\n',
#  'The best we can',
#  'st we can do, t',
#  'can do, to para',
#  ', to paraphrase',
#  'araphrase Polla',
#  'ase Pollan, is ',
#  'llan, is to eat',
#  'is to eat whole',
#  'eat whole foods',
#  'ole foods, most',
#  'ods, mostly pla',
#  'ostly plants, a',
#  'plants, and not',
#  ', and not too m',
#  ' not too much.\n',
#  'I tried the pal',
#  'd the paleo die',
#  'paleo diet, whi',
#  'diet, which is ',
#  'which is the ca',
#  'is the caveman ',
#  ' caveman diet -',
#  'an diet - lots ',
#  't - lots of mea',
#  'ts of meat. And',
#  'meat. And I tri',
#  'And I tried the',
#  'tried the calor',
#  'the calorie res',
#  'lorie restricti',
#  'restriction die',
#  'ction diet The ',
#  'diet The idea i',
#  'he idea is that',
#  'a is that if yo',
#  'hat if you eat ',
#  ' you eat very, ',
#  'at very, very l',
#  'y, very little ',
#  'y little - if y',
#  "le - if you're ",
#  "f you're on the",
#  're on the verge',
#  'the verge of st',
#  'rge of starvati',
#  ' starvation, yo',
#  'ation, you will',
#  ' you will live ',
#  'ill live a very',
#  've a very long ',
#  'ery long time, ',
#  'ng time, whethe',
#  'e, whether or n',
#  'ther or not you',
#  'r not you want ',
#  'you want to, of',
#  'nt to, of cours',
#  'to, of course.\n',
#  'My goal? To tes',
#  'l? To test out ',
#  'test out every ',
#  'ut every diet a',
#  'ry diet and exe',
#  't and exercise ',
#  'exercise regime',
#  'se regimen on p',
#  'imen on planet ',
#  'n planet earth ',
#  'et earth and fi',
#  'th and figure o',
#  ' figure out whi',
#  'e out which wor',
#  'which work best',
#  'work best. I sw',
#  'est. I sweated,',
#  ' sweated, I coo',
#  'ed, I cooked, I',
#  'cooked, I learn',
#  ', I learned to ',
#  'arned to pole d',
#  'to pole dance. ',
#  'e dance. In the',
#  'e. In the end, ',
#  'the end, I lost',
#  'd, I lost weigh',
#  'ost weight, low',
#  'ight, lowered m',
#  'lowered my chol',
#  'd my cholestero',
#  'holesterol and ',
#  'erol and double',
#  'nd doubled my e',
#  'bled my energy ',
#  'y energy level.',
#  'gy level. I fee',
#  'el. I feel bett',
#  'feel better tha',
#  'etter than I ev',
#  'than I ever hav',
#  'n I ever have.\n',
#  'I pledged to be',
#  'ged to become t',
#  ' become the wor',
#  "e the world's g",
#  "world's greates",
#  's greatest expe',
#  'test expert in ',
#  'xpert in a fiel',
#  'in a field I kn',
#  'ield I knew not',
#  ' knew nothing a',
#  'nothing about.\n',
#  "It's sort of my",
#  'ort of my job t',
#  ' my job to feel',
#  'b to feel good.',
#  ' to feel good.\n',
#  'I was what they',
#  'what they call ',
#  "hey call 'skinn",
#  "ll 'skinny fat'",
#  "inny fat' - a b",
#  "at' - a body th",
#  'a body that res',
#  ' that resembled',
#  'resembled a pyt',
#  'led a python af',
#  'python after sw',
#  ' after swallowi',
#  ' swallowing a g',
#  'lowing a goat.\n',
#  'I was very good',
#  'very good at si',
#  'ood at sitting.',
#  ' sitting. But I',
#  'ng. But I just ',
#  't I just read s',
#  'st read so much',
#  'd so much resea',
#  'uch research ab',
#  'search about ho',
#  ' about how horr',
#  ' how horrible s',
#  'orrible sitting',
#  'e sitting is fo',
#  'ing is for you.',
#  " for you. It's ",
#  "ou. It's like, ",
#  "'s like, it's r",
#  "e, it's really ",
#  's really bad. I',
#  "ly bad. It's li",
#  ". It's like Pau",
#  ' like Paula-Dee',
#  'Paula-Deen-glaz',
#  'Deen-glazed-bac',
#  'lazed-bacon-dou',
#  'bacon-doughnut ',
#  'doughnut bad. S',
#  'ut bad. So I no',
#  '. So I now move',
#  ' now move aroun',
#  'ove around as m',
#  'ound as much as',
#  's much as possi',
#  'h as possible.\n',
#  "There's a very ",
#  's a very passio',
#  'ry passionate p',
#  'sionate pro-che',
#  'e pro-chewing m',
#  'chewing movemen',
#  'g movement on t',
#  'ment on the Int',
#  'n the Internet ',
#  'Internet called',
#  'et called Chewd',
#  'led Chewdiasm. ',
#  'ewdiasm. They s',
#  'm. They say tha',
#  'y say that we s',
#  'that we should ',
#  'e should be che',
#  'ld be chewing 5',
#  'chewing 50 to 1',
#  'g 50 to 100 tim',
#  'o 100 times per',
#  'times per mouth',
#  'per mouthful, w',
#  'uthful, which i',
#  ', which is insa',
#  'h is insane. I ',
#  'nsane. I tried ',
#  ' I tried that. ',
#  'ed that. It tak',
#  't. It takes lik',
#  'takes like a da',
#  'like a day and ',
#  ' day and a half',
#  'nd a half to ea',
#  'alf to eat a sa',
#  ' eat a sandwich',
#  ' sandwich. But ',
#  'ich. But their ',
#  'ut their basic ',
#  'ir basic idea i',
#  'ic idea is righ',
#  'a is right. If ',
#  'ight. If you ch',
#  'If you chew, yo',
#  " chew, you'll e",
#  " you'll eat slo",
#  'l eat slower an',
#  'slower and you ',
#  ' and you will g',
#  'ou will get mor',
#  'l get more nutr',
#  'more nutrients.',
#  'ore nutrients.\n',
#  'You have to dre',
#  've to dream bef',
#  'dream before yo',
#  'before your dre',
#  ' your dreams ca',
#  'dreams can come',
#  ' can come true.',
#  'can come true.\n',
#  'If a country is',
#  'ountry is to be',
#  ' is to be corru',
#  ' be corruption ',
#  'rruption free a',
#  'on free and bec',
#  'e and become a ',
#  'become a nation',
#  ' a nation of be',
#  'ion of beautifu',
#  ' beautiful mind',
#  'iful minds, I s',
#  'inds, I strongl',
#  'I strongly feel',
#  'ngly feel there',
#  'eel there are t',
#  'ere are three k',
#  'e three key soc',
#  'e key societal ',
#  'societal member',
#  'al members who ',
#  'bers who can ma',
#  'ho can make a d',
#  ' make a differe',
#  'a difference. T',
#  'erence. They ar',
#  '. They are the ',
#  ' are the father',
#  'he father, the ',
#  'her, the mother',
#  'he mother and t',
#  'her and the tea',
#  'd the teacher.\n',
#  'Look at the sky',
#  't the sky. We a',
#  'sky. We are not',
#  'e are not alone',
#  'not alone. The ',
#  'one. The whole ',
#  'he whole univer',
#  'le universe is ',
#  'verse is friend',
#  'is friendly to ',
#  'endly to us and',
#  'to us and consp',
#  'and conspires o',
#  'nspires only to',
#  's only to give ',
#  ' to give the be',
#  've the best to ',
#  ' best to those ',
#  'to those who dr',
#  'se who dream an',
#  ' dream and work',
#  'ream and work.\n',
#  'Great dreams of',
#  'dreams of great',
#  ' of great dream',
#  'eat dreamers ar',
#  'eamers are alwa',
#  ' are always tra',
#  'lways transcend',
#  's transcended.\n',
#  'My message, esp',
#  'sage, especiall',
#  'especially to y',
#  'ally to young p',
#  'o young people ',
#  'g people is to ',
#  'le is to have c',
#  'to have courage',
#  'e courage to th',
#  'age to think di',
#  ' think differen',
#  ' differently, c',
#  'rently, courage',
#  ', courage to in',
#  'age to invent, ',
#  ' invent, to tra',
#  't, to travel th',
#  'travel the unex',
#  ' the unexplored',
#  'nexplored path,',
#  'red path, coura',
#  'th, courage to ',
#  'urage to discov',
#  'to discover the',
#  'cover the impos',
#  'the impossible ',
#  'possible and to',
#  'le and to conqu',
#  ' to conquer the',
#  'nquer the probl',
#  'the problems an',
#  'oblems and succ',
#  ' and succeed. T',
#  'ucceed. These a',
#  '. These are gre',
#  'e are great qua',
#  'great qualities',
#  'qualities that ',
#  'ies that they m',
#  'at they must wo',
#  'y must work tow',
#  ' work towards. ',
#  'towards. This i',
#  's. This is my m',
#  's is my message',
#  'y message to th',
#  'age to the youn',
#  ' the young peop',
#  ' young people.\n',
#  'To succeed in y',
#  'ceed in your mi',
#  'n your mission,',
#  ' mission, you m',
#  'on, you must ha',
#  'u must have sin',
#  ' have single-mi',
#  'single-minded d',
#  '-minded devotio',
#  'd devotion to y',
#  'tion to your go',
#  ' to your goal.\n',
#  'Let me define a',
#  ' define a leade',
#  'e a leader. He ',
#  'ader. He must h',
#  'He must have vi',
#  't have vision a',
#  ' vision and pas',
#  'n and passion a',
#  'passion and not',
#  'n and not be af',
#  'not be afraid o',
#  ' afraid of any ',
#  'd of any proble',
#  'ny problem. Ins',
#  'blem. Instead, ',
#  'Instead, he sho',
#  'd, he should kn',
#  'should know how',
#  ' know how to de',
#  'how to defeat i',
#  ' defeat it. Mos',
#  't it. Most impo',
#  'Most importantl',
#  'mportantly, he ',
#  'ntly, he must w',
#  'he must work wi',
#  't work with int',
#  ' with integrity',
#  'ith integrity.\n',
#  'When we tackle ',
#  'e tackle obstac',
#  'le obstacles, w',
#  'tacles, we find',
#  ', we find hidde',
#  'ind hidden rese',
#  'dden reserves o',
#  'eserves of cour',
#  's of courage an',
#  'ourage and resi',
#  ' and resilience',
#  'esilience we di',
#  'nce we did not ',
#  ' did not know w',
#  'ot know we had.',
#  'w we had. And i',
#  'ad. And it is o',
#  'd it is only wh',
#  's only when we ',
#  ' when we are fa',
#  'we are faced wi',
#  ' faced with fai',
#  ' with failure d',
#  'failure do we r',
#  'e do we realise',
#  'e realise that ',
#  'ise that these ',
#  'at these resour',
#  'se resources we',
#  'ources were alw',
#  ' were always th',
#  'always there wi',
#  ' there within u',
#  ' within us. We ',
#  'n us. We only n',
#  'We only need to',
#  'y need to find ',
#  ' to find them a',
#  'nd them and mov',
#  'm and move on w',
#  'move on with ou',
#  'n with our live',
#  'ith our lives.\n',
#  'Climbing to the',
#  'ng to the top d',
#  'the top demands',
#  'p demands stren',
#  'nds strength, w',
#  'rength, whether',
#  ', whether it is',
#  'her it is to th',
#  ' is to the top ',
#  ' the top of Mou',
#  'op of Mount Eve',
#  'Mount Everest o',
#  'Everest or to t',
#  't or to the top',
#  'o the top of yo',
#  'top of your car',
#  'f your career.\n',
#  'The world has t',
#  'rld has today 5',
#  's today 546 nuc',
#  'y 546 nuclear p',
#  'nuclear plants ',
#  'r plants genera',
#  'ts generating e',
#  'erating electri',
#  'g electricity. ',
#  'tricity. Their ',
#  'y. Their experi',
#  'ir experience i',
#  'erience is bein',
#  'e is being cont',
#  'eing continuous',
#  'ontinuously res',
#  'ously researche',
#  'researched, and',
#  'ched, and feedb',
#  'and feedback sh',
#  'edback should b',
#  ' should be prov',
#  'd be provided t',
#  'rovided to all.',
#  'd to all. Nucle',
#  'll. Nuclear sci',
#  'clear scientist',
#  'scientists have',
#  'ists have to in',
#  'ave to interact',
#  ' interact with ',
#  'act with the pe',
#  'th the people o',
#  ' people of the ',
#  'e of the nation',
#  'he nation, and ',
#  'ion, and academ',
#  'nd academic ins',
#  'demic instituti',
#  'institutions co',
#  'utions continuo',
#  ' continuously u',
#  'nuously update ',
#  'y update nuclea',
#  'te nuclear powe',
#  'lear power gene',
#  'ower generation',
#  'eneration techn',
#  'ion technology ',
#  'chnology and sa',
#  'gy and safety.\n',
#  'God, our Creato',
#  'ur Creator, has',
#  'ator, has store',
#  'has stored with',
#  'ored within our',
#  'ithin our minds',
#  'our minds and p',
#  'nds and persona',
#  'd personalities',
#  'onalities, grea',
#  'ies, great pote',
#  'reat potential ',
#  'otential streng',
#  'al strength and',
#  'ength and abili',
#  'and ability. Pr',
#  'ility. Prayer h',
#  ' Prayer helps u',
#  'r helps us tap ',
#  's us tap and de',
#  'ap and develop ',
#  ' develop these ',
#  'op these powers',
#  ' these powers.\n',
#  'Excellence is a',
#  'ence is a conti',
#  's a continuous ',
#  'ntinuous proces',
#  'us process and ',
#  'cess and not an',
#  'nd not an accid',
#  't an accident.\n',
#  'Creativity is t',
#  'vity is the key',
#  's the key to su',
#  'key to success ',
#  ' success in the',
#  'ss in the futur',
#  'the future, and',
#  'ture, and prima',
#  'and primary edu',
#  'imary education',
#  'education is wh',
#  'ion is where te',
#  ' where teachers',
#  ' teachers can b',
#  'ers can bring c',
#  'n bring creativ',
#  'g creativity in',
#  'tivity in child',
#  ' in children at',
#  'ildren at that ',
#  ' at that level.',
#  'at that level.\n',
#  'The bird is pow',
#  'rd is powered b',
#  'powered by its ',
#  'd by its own li',
#  'ts own life and',
#  ' life and by it',
#  'and by its moti',
#  ' its motivation',
#  'ts motivation.\n',
#  'One of the very',
#  ' the very impor',
#  'ery important c',
#  'portant charact',
#  't characteristi',
#  'acteristics of ',
#  'stics of a stud',
#  'of a student is',
#  'tudent is to qu',
#  ' is to question',
#  ' question. Let ',
#  'ion. Let the st',
#  'et the students',
#  ' students ask q',
#  'nts ask questio',
#  'ask questions.\n',
#  'Let us sacrific',
#  ' sacrifice our ',
#  'fice our today ',
#  'ur today so tha',
#  'ay so that our ',
#  'that our childr',
#  'ur children can',
#  'ldren can have ',
#  'can have a bett',
#  've a better tom',
#  'etter tomorrow.',
#  'tter tomorrow.\n',
#  'Life is a diffi',
#  's a difficult g',
#  'fficult game. Y',
#  't game. You can',
#  '. You can win i',
#  'can win it only',
#  'n it only by re',
#  'nly by retainin',
#  ' retaining your',
#  'ning your birth',
#  'our birthright ',
#  'rthright to be ',
#  'ht to be a pers',
#  'o be a person.\n',
#  'We should not g',
#  'uld not give up',
#  't give up and w',
#  ' up and we shou',
#  'd we should not',
#  'hould not allow',
#  'not allow the p',
#  'low the problem',
#  'e problem to de',
#  'lem to defeat u',
#  ' to defeat us.\n',
#  'Man needs his d',
#  'eds his difficu',
#  's difficulties ',
#  'iculties becaus',
#  'es because they',
#  'ause they are n',
#  'hey are necessa',
#  'e necessary to ',
#  'ssary to enjoy ',
#  'to enjoy succes',
#  'enjoy success.\n',
#  'Almost half of ',
#  ' half of the po',
#  'of the populati',
#  ' population of ',
#  'ation of the wo',
#  'of the world li',
#  ' world lives in',
#  ' lives in rural',
#  ' in rural regio',
#  'ral regions and',
#  'gions and mostl',
#  'and mostly in a',
#  'stly in a state',
#  'n a state of po',
#  'ate of poverty.',
#  ' poverty. Such ',
#  'ty. Such inequa',
#  'ch inequalities',
#  'qualities in hu',
#  'ies in human de',
#  ' human developm',
#  ' development ha',
#  'opment have bee',
#  ' have been one ',
#  'been one of the',
#  'ne of the prima',
#  'the primary rea',
#  'imary reasons f',
#  'reasons for unr',
#  's for unrest an',
#  'unrest and, in ',
#  ' and, in some p',
#  'in some parts o',
#  'e parts of the ',
#  's of the world,',
#  'he world, even ',
#  'ld, even violen',
#  'even violence.\n',
#  'We will be reme',
#  'l be remembered',
#  'emembered only ',
#  ...]

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
x.shape, y.shape, len(chars)
# Out:
# ((753142, 15, 73), (753142, 73), 73)

# %%
## Model 
print('Build model...')
input_sequences = Input((maxlen, len(chars)) , name="input_sequences")
lstm = Bidirectional(LSTM(256, return_sequences= True, input_shape=(maxlen, len(chars))), name = 'bidirectional')(input_sequences)
lstm = Dropout(0.1, name = 'dropout_bidirectional_lstm')(lstm)
lstm = LSTM(64, input_shape=(maxlen, len(chars)), name = 'lstm')(lstm)
lstm = Dropout(0.1,  name = 'drop_out_lstm')(lstm)

dense = Dense(15 * len(chars), name = 'first_dense')(lstm)
dense = Dropout(0.1,  name = 'drop_out_first_dense')(dense)
dense = Dense(5 * len(chars), name = 'second_dense')(dense)
dense = Dropout(0.1,  name = 'drop_out_second_dense')(dense)
dense = Dense(len(chars), name = 'last_dense')(dense)

next_char = Activation('softmax', name = 'activation')(dense)

model = Model([input_sequences], next_char)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# Out:
# Build model...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_sequences (InputLayer) (None, 15, 73)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 15, 512)           675840
# _________________________________________________________________
# dropout_bidirectional_lstm ( (None, 15, 512)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                147712
# _________________________________________________________________
# drop_out_lstm (Dropout)      (None, 64)                0
# _________________________________________________________________
# first_dense (Dense)          (None, 1095)              71175
# _________________________________________________________________
# drop_out_first_dense (Dropou (None, 1095)              0
# _________________________________________________________________
# second_dense (Dense)         (None, 365)               400040
# _________________________________________________________________
# drop_out_second_dense (Dropo (None, 365)               0
# _________________________________________________________________
# last_dense (Dense)           (None, 73)                26718
# _________________________________________________________________
# activation (Activation)      (None, 73)                0
# =================================================================
# Total params: 1,321,485
# Trainable params: 1,321,485
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit([x], y,
         batch_size=128,
          epochs= 15
         )
# Out:
# Epoch 1/15
# 753142/753142 [==============================] - 1232s 2ms/step - loss: 1.8665
# Epoch 2/15
# 753142/753142 [==============================] - 1282s 2ms/step - loss: 1.5284
# Epoch 3/15
# 753142/753142 [==============================] - 1276s 2ms/step - loss: 1.4250
# Epoch 4/15
# 753142/753142 [==============================] - 1278s 2ms/step - loss: 1.3667
# Epoch 5/15
# 753142/753142 [==============================] - 1247s 2ms/step - loss: 1.3270
# Epoch 6/15
# 753142/753142 [==============================] - 1199s 2ms/step - loss: 1.2970
# Epoch 7/15
# 753142/753142 [==============================] - 1202s 2ms/step - loss: 1.2734
# Epoch 8/15
# 753142/753142 [==============================] - 1197s 2ms/step - loss: 1.2530
# Epoch 9/15
# 753142/753142 [==============================] - 1195s 2ms/step - loss: 1.2353
# Epoch 10/15
# 753142/753142 [==============================] - 1191s 2ms/step - loss: 1.2198
# Epoch 11/15
# 753142/753142 [==============================] - 1187s 2ms/step - loss: 1.2054
# Epoch 12/15
# 753142/753142 [==============================] - 1182s 2ms/step - loss: 1.1925
# Epoch 13/15
# 753142/753142 [==============================] - 1178s 2ms/step - loss: 1.1799
# Epoch 14/15
# 753142/753142 [==============================] - 1187s 2ms/step - loss: 1.1690
# Epoch 15/15
# 753142/753142 [==============================] - 1198s 2ms/step - loss: 1.1591

# %%
model.fit([x], y,
         batch_size=2048,
          epochs= 2
         )
# Out:
# Epoch 1/2
# 753142/753142 [==============================] - 959s 1ms/step - loss: 1.0823
# Epoch 2/2
# 753142/753142 [==============================] - 1106s 1ms/step - loss: 1.0619

# %%
model.fit([x], y,
         batch_size=1024,
          epochs= 2
         )
# Out:
# Epoch 1/2
# 753142/753142 [==============================] - 969s 1ms/step - loss: 1.0616
# Epoch 2/2
# 753142/753142 [==============================] - 980s 1ms/step - loss: 1.0574

# %%
two_first_words = [bigram for bigram in [' '.join(word_tokenize(quote)[:2]) for quote in quotes] if len(bigram) <= maxlen]

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate_quote(sentence = None, diversity = 0.8):
    
    if not sentence: ## if input is null then sample two first word from dataset
        random_index = np.random.randint(0, len(two_first_words))
        sentence = two_first_words[random_index]
        
    if len(sentence) > maxlen:
        sentence = sentence[-maxlen:]
    elif len(sentence) < maxlen:
        sentence = ' '*(maxlen - len(sentence)) + sentence
        
    generated = ''
    generated += sentence
    sys.stdout.write(generated)
    
    next_char = 'Empty'
    total_word = 0 
    
    max_word = 15
    
    while ((next_char not in ['\n', '.']) & (total_word <= 500)):
    
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        if next_char == ' ':
           total_word += 1
        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

# %%
generate_quote()
# Out:
#         I couldn't walk in the church.

# %%
generate_quote()
# Out:
#          You don't have to take on my family.

# %%
generate_quote()
# Out:
#       The legal songs on the same credit the long time, and you love a man without love, understanding.

# %%
generate_quote()
# Out:
#        Learn to know what the issue is my universe, how you do what they instead of beow.

# %%
generate_quote()
# Out:
#        My motto with the down and amazing state in the classic and face it because I was a DeficiI I would learn all the unity.

# %%
generate_quote()
# Out:
#        There is nothing without the past.

# %%
generate_quote()
# Out:
#      After much things that I had a good way to be able to place the material things in the form of our tatence will go to see their show in it.

# %%
generate_quote()
# Out:
#        Once you will love you so introversions who'll say there is important thing that are something good into something to be simpling my feet I could be a none is the real of a time to stand for video from an energy people.

# %%
generate_quote()
# Out:
#    A successful sadness of the game of our controversy for how hear, is wrong in the time, and I got a short men.

# %%
generate_quote()
# Out:
#    Happiness is so such a house why can hasten before, what you take every time with my encouraged by Phose.

# %%
generate_quote()
# Out:
#          If you are too lack friends and his things that are well in a books are not the volution of its heart that is a movie the banda used to always be a wanting to be long is confidentally good to one would be much more believe I do your poor.

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_char_2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_char_2.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
